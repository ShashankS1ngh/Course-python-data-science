# %% [markdown]
# <a href="https://colab.research.google.com/github/ShashankS1ngh/Course-python-data-science/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from urllib.request import urlretrieve
urlretrieve('https://hub.jovian.ml/wp-content/uploads/2020/09/italy-covid-daywise.csv',
            'italy-covid-daywise.csv')
urlretrieve('https://gist.githubusercontent.com/aakashns/8684589ef4f266116cdce023377fc9c8/raw/99ce3826b2a9d1e6d0bde7e9e559fc8b6e9ac88b/locations.csv',
            'locations.csv')
covid_df = pd.read_csv('italy-covid-daywise.csv')
covid_df['date'] = pd.to_datetime(covid_df.date)
covid_df['year'] = pd.DatetimeIndex(covid_df.date).year
covid_df['month'] = pd.DatetimeIndex(covid_df.date).month
covid_df['day'] = pd.DatetimeIndex(covid_df.date).day
covid_df['weekday'] = pd.DatetimeIndex(covid_df.date).weekday
covid_month_df = covid_df.groupby('month')[['new_cases', 'new_deaths', 'new_tests']].sum()
covid_df['total_cases'] = covid_df.new_cases.cumsum()
covid_df['total_deaths'] = covid_df.new_deaths.cumsum()
covid_df['total_tests'] = covid_df.new_tests.cumsum()
locations_df = pd.read_csv('locations.csv')
locations_df[locations_df.location=="Italy"]
covid_df['location'] = "Italy"
merged_df = covid_df.merge(locations_df, on="location")
merged_df['cases_per_million'] = merged_df.total_cases * 1e6 / merged_df.population
merged_df['deaths_per_million'] = merged_df.total_deaths * 1e6 / merged_df.population
merged_df['tests_per_million'] = merged_df.total_tests * 1e6 / merged_df.population
result_df = merged_df[['date',
                       'new_cases',
                       'total_cases',
                       'new_deaths',
                       'total_deaths',
                       'new_tests',
                       'total_tests',
                       'cases_per_million',
                       'deaths_per_million',
                       'tests_per_million']]
result_df.to_csv('results.csv', index=None)
result_df.new_cases.plot();

result_df.new_cases.plot()
result_df.new_deaths.plot();
result_df.total_cases.plot()
result_df.total_deaths.plot();
death_rate = result_df.total_deaths / result_df.total_cases
death_rate.plot(title='Death Rate');
positive_rates = result_df.total_cases / result_df.total_tests
positive_rates.plot(title='Positive Rate');
covid_month_df.new_cases.plot(kind='bar');
covid_month_df.new_tests.plot(kind='bar')

# %%
result_df.new_deaths.plot();

# %%
merged_df
# Out:
#           date  new_cases  ...  deaths_per_million  tests_per_million
# 0   2019-12-31        0.0  ...            0.000000                NaN
# 1   2020-01-01        0.0  ...            0.000000                NaN
# 2   2020-01-02        0.0  ...            0.000000                NaN
# 3   2020-01-03        0.0  ...            0.000000                NaN
# 4   2020-01-04        0.0  ...            0.000000                NaN
# ..         ...        ...  ...                 ...                ...
# 243 2020-08-30     1444.0  ...          586.700753       69175.513516
# 244 2020-08-31     1365.0  ...          586.766910       69879.809125
# 245 2020-09-01      996.0  ...          586.866146       70779.467667
# 246 2020-09-02      975.0  ...          586.998461                NaN
# 247 2020-09-03     1326.0  ...          587.097697                NaN
#
# [248 rows x 20 columns]

# %%
locations_df
# Out:
#           location continent  ...  hospital_beds_per_thousand  gdp_per_capita
# 0      Afghanistan      Asia  ...                       0.500        1803.987
# 1          Albania    Europe  ...                       2.890       11803.431
# 2          Algeria    Africa  ...                       1.900       13913.839
# 3          Andorra    Europe  ...                         NaN             NaN
# 4           Angola    Africa  ...                         NaN        5819.495
# ..             ...       ...  ...                         ...             ...
# 207          Yemen      Asia  ...                       0.700        1479.147
# 208         Zambia    Africa  ...                       2.000        3689.251
# 209       Zimbabwe    Africa  ...                       1.700        1899.775
# 210          World       NaN  ...                       2.705       15469.207
# 211  International       NaN  ...                         NaN             NaN
#
# [212 rows x 6 columns]

# %%
(locations_df.location=="India")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 207    False
# 208    False
# 209    False
# 210    False
# 211    False
# Name: location, Length: 212, dtype: bool
